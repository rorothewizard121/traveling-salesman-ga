# %% [markdown]
# ## Genetic Algorithm for TSP

# %% [markdown]
# ### General outline:
# 1. Population Initialization
#     - Choose number of individuals the population will consist of. This value is generally kept constant.
# 2. Selection
#     - Using a specific selection method eg. fitness-proportionate, rank-based or tournament select individuals we will use in the next step.
# 3. Crossover
#     - Using a specific crossover method eg. PMX, k-point or uniform perform crossover on the selected parents.
# 4. Mutation
#     - Based on the mutation rate (probability that any individual/gene is changed) apply mutation on population members.
# 5. Survivor Selection
#     - Using a selection method again choose the individuals of the current population that will make up the next generation.
# 7. Termination Check
#     - When predefined termination criteria are met return the results of the algorithm.

# %% [markdown]
# ## Apply Principles to TSP:

# %% [markdown]
# ### What we will need:
# - Classes:
#     - `Individual, constructor-parameters: n_cities (int), permutation (list), tsplib_problem (tsplib95.models.StandardProblem)`
#     - `Population, constructor-parameters: n_cities (int), tsplib_problem (tsplib95.models.StandardProblem), population_size (int), tournament_size (int)`
#     - `GeneticAlgorithm: constructor-parameters: tsplib_problem (tsplib95.models.StandardProblem), population_size (int), generations (int), mutation_rate (float), tournament_size (int)`
#
# - Functions:
#     - Class:
#         - Individual:
#             - `fitness(), return: (int)`
#             - `mutate(), parameters: mutation_rate (float)`
#         - Population:
#             - `initialize_population()`
#             - `tournament_selection(), return: (Individual) `
#             - `pmx(), parameters: parent1 (Individual), parent2 (Individual), return: (Individual)`
#             - `create_next_generation(), parameters: mutation_rate (float)`
#             - `evaluate_population()`
#             - `get_best_individual(), return: (Individual)`
#         - GeneticAlgorithm:
#             - `run()`

# %%
import random
import tsplib95

# %%
class Individual:
    def __init__(self, n_cities, permutation, tsplib_problem):
        self.n_cities = n_cities 
        self.permutation = permutation
        self.tsplib_problem = tsplib_problem
        self.total_distance = 0 

        self.fitness()


    def fitness(self):
        total_distance = 0
        for i in range(self.n_cities - 1):
            total_distance += self.tsplib_problem.get_weight(self.permutation[i], self.permutation[i + 1])

        self.total_distance = total_distance

    def mutate(self, mutation_rate):
        if random.random() < mutation_rate:
            i, j = random.sample(range(self.n_cities), 2)
            self.permutation[i], self.permutation[j] = self.permutation[j], self.permutation[i]

# %%
class Population:
    def __init__(self, n_cities, tsplib_problem, population_size=100, tournament_size=5):
        self.n_cities = n_cities
        self.tsplib_problem = tsplib_problem
        self.population_size = population_size
        self.tournament_size = tournament_size 
        self.individuals = []

    def initialize_population(self):
        self.individuals = []
        for _ in range(self.population_size):
            permutation = list(self.tsplib_problem.get_nodes())
            random.shuffle(permutation)
            individual = Individual(self.n_cities, permutation, self.tsplib_problem)
            self.individuals.append(individual)
    
    def tournament_selection(self):
        selected = random.sample(self.individuals, self.tournament_size)
        return min(selected, key=lambda ind: ind.total_distance)

    def pmx(self, parent1, parent2):
        start, end = sorted(random.sample(range(self.n_cities), 2))
        child_permutation = [None] * self.n_cities

        child_permutation[start:end] = parent1.permutation[start:end]

        for i in range(self.n_cities):
            if child_permutation[i] is None:
                for city in parent2.permutation:
                    if city not in child_permutation:
                        child_permutation[i] = city
                        break

        return Individual(self.n_cities, child_permutation, self.tsplib_problem)

    def create_next_generation(self, mutation_rate=0.01):
        new_individuals = []
        while len(new_individuals) < self.population_size:
            parent1 = self.tournament_selection()
            parent2 = self.tournament_selection()
            child = self.pmx(parent1, parent2)
            child.mutate(mutation_rate)
            new_individuals.append(child)

        self.individuals = new_individuals

    def evaluate_population(self):
        for individual in self.individuals:
            individual.fitness()

    def get_best_individual(self):
        return min(self.individuals, key=lambda ind: ind.total_distance)

# %%
class GeneticAlgorithm:
    def __init__(self, tsplib_problem, population_size=100, generations=500, mutation_rate=0.01, tournament_size=5):
        self.tsplib_problem = tsplib_problem
        self.population_size = population_size
        self.generations = generations
        self.epochs = 0
        self.mutation_rate = mutation_rate
        self.tournament_size = tournament_size
        self.n_cities = len(list(tsplib_problem.get_nodes()))
        self.population = Population(self.n_cities, tsplib_problem, population_size, tournament_size)

    def run(self):
        self.population.initialize_population()
        for generation in range(self.generations):
            self.population.evaluate_population()
            best_individual = self.population.get_best_individual()
            print(f"Generation {generation}: Best Distance = {best_individual.total_distance}")
            self.population.create_next_generation(self.mutation_rate)
            self.epochs += 1

        return self.population.get_best_individual()

# %%
if __name__ == "__main__":
    problem = tsplib95.load("data/berlin52.tsp") 
    ga = GeneticAlgorithm(problem, population_size=100, generations=500, mutation_rate=0.1, tournament_size=5)
    best_solution = ga.run()
    print(f"Best solution found: {best_solution.permutation} with distance {best_solution.total_distance}")
# Out:
# Generation 0: Best Distance = 25669
# Generation 1: Best Distance = 24737
# Generation 2: Best Distance = 23576
# Generation 3: Best Distance = 22955
# Generation 4: Best Distance = 21507
# Generation 5: Best Distance = 21367
# Generation 6: Best Distance = 20906
# Generation 7: Best Distance = 20712
# Generation 8: Best Distance = 20254
# Generation 9: Best Distance = 19994
# Generation 10: Best Distance = 18338
# Generation 11: Best Distance = 18281
# Generation 12: Best Distance = 18138
# Generation 13: Best Distance = 17250
# Generation 14: Best Distance = 17105
# Generation 15: Best Distance = 16879
# Generation 16: Best Distance = 16617
# Generation 17: Best Distance = 16357
# Generation 18: Best Distance = 15922
# Generation 19: Best Distance = 15887
# Generation 20: Best Distance = 15598
# Generation 21: Best Distance = 15567
# Generation 22: Best Distance = 15225
# Generation 23: Best Distance = 15448
# Generation 24: Best Distance = 15411
# Generation 25: Best Distance = 15269
# Generation 26: Best Distance = 15007
# Generation 27: Best Distance = 14907
# Generation 28: Best Distance = 14694
# Generation 29: Best Distance = 14762
# Generation 30: Best Distance = 14723
# Generation 31: Best Distance = 14437
# Generation 32: Best Distance = 14437
# Generation 33: Best Distance = 14437
# Generation 34: Best Distance = 14281
# Generation 35: Best Distance = 14025
# Generation 36: Best Distance = 13968
# Generation 37: Best Distance = 13964
# Generation 38: Best Distance = 13618
# Generation 39: Best Distance = 13570
# Generation 40: Best Distance = 13566
# Generation 41: Best Distance = 13377
# Generation 42: Best Distance = 13373
# Generation 43: Best Distance = 13373
# Generation 44: Best Distance = 13326
# Generation 45: Best Distance = 13003
# Generation 46: Best Distance = 13003
# Generation 47: Best Distance = 13003
# Generation 48: Best Distance = 12991
# Generation 49: Best Distance = 12942
# Generation 50: Best Distance = 12660
# Generation 51: Best Distance = 12660
# Generation 52: Best Distance = 12605
# Generation 53: Best Distance = 12447
# Generation 54: Best Distance = 12395
# Generation 55: Best Distance = 12346
# Generation 56: Best Distance = 12346
# Generation 57: Best Distance = 12291
# Generation 58: Best Distance = 12291
# Generation 59: Best Distance = 12291
# Generation 60: Best Distance = 12212
# Generation 61: Best Distance = 12212
# Generation 62: Best Distance = 12212
# Generation 63: Best Distance = 12070
# Generation 64: Best Distance = 12070
# Generation 65: Best Distance = 12070
# Generation 66: Best Distance = 12070
# Generation 67: Best Distance = 12070
# Generation 68: Best Distance = 11812
# Generation 69: Best Distance = 11812
# Generation 70: Best Distance = 11662
# Generation 71: Best Distance = 11620
# Generation 72: Best Distance = 11593
# Generation 73: Best Distance = 11593
# Generation 74: Best Distance = 11593
# Generation 75: Best Distance = 11593
# Generation 76: Best Distance = 11593
# Generation 77: Best Distance = 11593
# Generation 78: Best Distance = 11593
# Generation 79: Best Distance = 11593
# Generation 80: Best Distance = 11593
# Generation 81: Best Distance = 11593
# Generation 82: Best Distance = 11430
# Generation 83: Best Distance = 11430
# Generation 84: Best Distance = 11430
# Generation 85: Best Distance = 11430
# Generation 86: Best Distance = 11430
# Generation 87: Best Distance = 11430
# Generation 88: Best Distance = 11430
# Generation 89: Best Distance = 11430
# Generation 90: Best Distance = 11383
# Generation 91: Best Distance = 11383
# Generation 92: Best Distance = 11339
# Generation 93: Best Distance = 11268
# Generation 94: Best Distance = 11184
# Generation 95: Best Distance = 11184
# Generation 96: Best Distance = 11159
# Generation 97: Best Distance = 11159
# Generation 98: Best Distance = 11103
# Generation 99: Best Distance = 11103
# Generation 100: Best Distance = 11078
# Generation 101: Best Distance = 11078
# Generation 102: Best Distance = 11029
# Generation 103: Best Distance = 11029
# Generation 104: Best Distance = 11029
# Generation 105: Best Distance = 11029
# Generation 106: Best Distance = 11029
# Generation 107: Best Distance = 11029
# Generation 108: Best Distance = 11029
# Generation 109: Best Distance = 11029
# Generation 110: Best Distance = 11029
# Generation 111: Best Distance = 10959
# Generation 112: Best Distance = 10959
# Generation 113: Best Distance = 10857
# Generation 114: Best Distance = 10857
# Generation 115: Best Distance = 10894
# Generation 116: Best Distance = 10894
# Generation 117: Best Distance = 10837
# Generation 118: Best Distance = 10837
# Generation 119: Best Distance = 10662
# Generation 120: Best Distance = 10662
# Generation 121: Best Distance = 10486
# Generation 122: Best Distance = 10486
# Generation 123: Best Distance = 10486
# Generation 124: Best Distance = 10449
# Generation 125: Best Distance = 10449
# Generation 126: Best Distance = 10449
# Generation 127: Best Distance = 10449
# Generation 128: Best Distance = 10449
# Generation 129: Best Distance = 10449
# Generation 130: Best Distance = 10404
# Generation 131: Best Distance = 10404
# Generation 132: Best Distance = 10404
# Generation 133: Best Distance = 10404
# Generation 134: Best Distance = 10395
# Generation 135: Best Distance = 10395
# Generation 136: Best Distance = 10395
# Generation 137: Best Distance = 10395
# Generation 138: Best Distance = 10395
# Generation 139: Best Distance = 10395
# Generation 140: Best Distance = 10395
# Generation 141: Best Distance = 10395
# Generation 142: Best Distance = 10395
# Generation 143: Best Distance = 10395
# Generation 144: Best Distance = 10395
# Generation 145: Best Distance = 10395
# Generation 146: Best Distance = 10395
# Generation 147: Best Distance = 10392
# Generation 148: Best Distance = 10392
# Generation 149: Best Distance = 10392
# Generation 150: Best Distance = 10392
# Generation 151: Best Distance = 10392
# Generation 152: Best Distance = 10392
# Generation 153: Best Distance = 10392
# Generation 154: Best Distance = 10392
# Generation 155: Best Distance = 10392
# Generation 156: Best Distance = 10392
# Generation 157: Best Distance = 10392
# Generation 158: Best Distance = 10392
# Generation 159: Best Distance = 10392
# Generation 160: Best Distance = 10392
# Generation 161: Best Distance = 10392
# Generation 162: Best Distance = 10360
# Generation 163: Best Distance = 10351
# Generation 164: Best Distance = 10351
# Generation 165: Best Distance = 10351
# Generation 166: Best Distance = 10351
# Generation 167: Best Distance = 10351
# Generation 168: Best Distance = 10351
# Generation 169: Best Distance = 10351
# Generation 170: Best Distance = 10351
# Generation 171: Best Distance = 10351
# Generation 172: Best Distance = 10351
# Generation 173: Best Distance = 10351
# Generation 174: Best Distance = 10351
# Generation 175: Best Distance = 10351
# Generation 176: Best Distance = 10347
# Generation 177: Best Distance = 10347
# Generation 178: Best Distance = 10347
# Generation 179: Best Distance = 10347
# Generation 180: Best Distance = 10347
# Generation 181: Best Distance = 10347
# Generation 182: Best Distance = 10347
# Generation 183: Best Distance = 10347
# Generation 184: Best Distance = 10347
# Generation 185: Best Distance = 10222
# Generation 186: Best Distance = 10222
# Generation 187: Best Distance = 10222
# Generation 188: Best Distance = 10222
# Generation 189: Best Distance = 10222
# Generation 190: Best Distance = 10222
# Generation 191: Best Distance = 10222
# Generation 192: Best Distance = 10170
# Generation 193: Best Distance = 10170
# Generation 194: Best Distance = 10170
# Generation 195: Best Distance = 10170
# Generation 196: Best Distance = 10170
# Generation 197: Best Distance = 10170
# Generation 198: Best Distance = 10170
# Generation 199: Best Distance = 10135
# Generation 200: Best Distance = 10135
# Generation 201: Best Distance = 10135
# Generation 202: Best Distance = 10135
# Generation 203: Best Distance = 10135
# Generation 204: Best Distance = 10135
# Generation 205: Best Distance = 10135
# Generation 206: Best Distance = 10135
# Generation 207: Best Distance = 10135
# Generation 208: Best Distance = 10135
# Generation 209: Best Distance = 10135
# Generation 210: Best Distance = 10135
# Generation 211: Best Distance = 10135
# Generation 212: Best Distance = 10135
# Generation 213: Best Distance = 10135
# Generation 214: Best Distance = 10135
# Generation 215: Best Distance = 10135
# Generation 216: Best Distance = 10135
# Generation 217: Best Distance = 10135
# Generation 218: Best Distance = 10135
# Generation 219: Best Distance = 10135
# Generation 220: Best Distance = 10135
# Generation 221: Best Distance = 10135
# Generation 222: Best Distance = 10135
# Generation 223: Best Distance = 10135
# Generation 224: Best Distance = 10128
# Generation 225: Best Distance = 10007
# Generation 226: Best Distance = 10128
# Generation 227: Best Distance = 10109
# Generation 228: Best Distance = 10109
# Generation 229: Best Distance = 10007
# Generation 230: Best Distance = 10007
# Generation 231: Best Distance = 10007
# Generation 232: Best Distance = 10005
# Generation 233: Best Distance = 10005
# Generation 234: Best Distance = 10005
# Generation 235: Best Distance = 10005
# Generation 236: Best Distance = 10005
# Generation 237: Best Distance = 10005
# Generation 238: Best Distance = 10005
# Generation 239: Best Distance = 10005
# Generation 240: Best Distance = 10005
# Generation 241: Best Distance = 10005
# Generation 242: Best Distance = 10005
# Generation 243: Best Distance = 10005
# Generation 244: Best Distance = 10005
# Generation 245: Best Distance = 10005
# Generation 246: Best Distance = 10005
# Generation 247: Best Distance = 10005
# Generation 248: Best Distance = 10005
# Generation 249: Best Distance = 10005
# Generation 250: Best Distance = 10005
# Generation 251: Best Distance = 10005
# Generation 252: Best Distance = 10005
# Generation 253: Best Distance = 10005
# Generation 254: Best Distance = 10005
# Generation 255: Best Distance = 10005
# Generation 256: Best Distance = 10005
# Generation 257: Best Distance = 10005
# Generation 258: Best Distance = 10005
# Generation 259: Best Distance = 10005
# Generation 260: Best Distance = 10005
# Generation 261: Best Distance = 10005
# Generation 262: Best Distance = 10005
# Generation 263: Best Distance = 10005
# Generation 264: Best Distance = 10005
# Generation 265: Best Distance = 10005
# Generation 266: Best Distance = 10005
# Generation 267: Best Distance = 10005
# Generation 268: Best Distance = 10005
# Generation 269: Best Distance = 10005
# Generation 270: Best Distance = 10005
# Generation 271: Best Distance = 10005
# Generation 272: Best Distance = 10005
# Generation 273: Best Distance = 10005
# Generation 274: Best Distance = 10005
# Generation 275: Best Distance = 10005
# Generation 276: Best Distance = 10005
# Generation 277: Best Distance = 10003
# Generation 278: Best Distance = 10003
# Generation 279: Best Distance = 10003
# Generation 280: Best Distance = 10003
# Generation 281: Best Distance = 10003
# Generation 282: Best Distance = 10003
# Generation 283: Best Distance = 10003
# Generation 284: Best Distance = 10003
# Generation 285: Best Distance = 10003
# Generation 286: Best Distance = 10003
# Generation 287: Best Distance = 10003
# Generation 288: Best Distance = 10003
# Generation 289: Best Distance = 10003
# Generation 290: Best Distance = 10003
# Generation 291: Best Distance = 10003
# Generation 292: Best Distance = 10003
# Generation 293: Best Distance = 10003
# Generation 294: Best Distance = 10003
# Generation 295: Best Distance = 10003
# Generation 296: Best Distance = 10003
# Generation 297: Best Distance = 10003
# Generation 298: Best Distance = 10003
# Generation 299: Best Distance = 10003
# Generation 300: Best Distance = 10003
# Generation 301: Best Distance = 10003
# Generation 302: Best Distance = 10003
# Generation 303: Best Distance = 10003
# Generation 304: Best Distance = 10003
# Generation 305: Best Distance = 10003
# Generation 306: Best Distance = 10003
# Generation 307: Best Distance = 10003
# Generation 308: Best Distance = 10003
# Generation 309: Best Distance = 10003
# Generation 310: Best Distance = 10003
# Generation 311: Best Distance = 9988
# Generation 312: Best Distance = 9988
# Generation 313: Best Distance = 9988
# Generation 314: Best Distance = 9988
# Generation 315: Best Distance = 9988
# Generation 316: Best Distance = 9988
# Generation 317: Best Distance = 9988
# Generation 318: Best Distance = 9988
# Generation 319: Best Distance = 9988
# Generation 320: Best Distance = 9988
# Generation 321: Best Distance = 9988
# Generation 322: Best Distance = 9988
# Generation 323: Best Distance = 9988
# Generation 324: Best Distance = 9988
# Generation 325: Best Distance = 9988
# Generation 326: Best Distance = 9988
# Generation 327: Best Distance = 9988
# Generation 328: Best Distance = 9988
# Generation 329: Best Distance = 9988
# Generation 330: Best Distance = 9988
# Generation 331: Best Distance = 9988
# Generation 332: Best Distance = 9988
# Generation 333: Best Distance = 9988
# Generation 334: Best Distance = 9988
# Generation 335: Best Distance = 9988
# Generation 336: Best Distance = 9988
# Generation 337: Best Distance = 9988
# Generation 338: Best Distance = 9988
# Generation 339: Best Distance = 9988
# Generation 340: Best Distance = 9882
# Generation 341: Best Distance = 9882
# Generation 342: Best Distance = 9882
# Generation 343: Best Distance = 9882
# Generation 344: Best Distance = 9882
# Generation 345: Best Distance = 9882
# Generation 346: Best Distance = 9882
# Generation 347: Best Distance = 9882
# Generation 348: Best Distance = 9882
# Generation 349: Best Distance = 9882
# Generation 350: Best Distance = 9882
# Generation 351: Best Distance = 9882
# Generation 352: Best Distance = 9882
# Generation 353: Best Distance = 9844
# Generation 354: Best Distance = 9844
# Generation 355: Best Distance = 9844
# Generation 356: Best Distance = 9840
# Generation 357: Best Distance = 9840
# Generation 358: Best Distance = 9840
# Generation 359: Best Distance = 9840
# Generation 360: Best Distance = 9840
# Generation 361: Best Distance = 9840
# Generation 362: Best Distance = 9840
# Generation 363: Best Distance = 9840
# Generation 364: Best Distance = 9840
# Generation 365: Best Distance = 9840
# Generation 366: Best Distance = 9840
# Generation 367: Best Distance = 9840
# Generation 368: Best Distance = 9840
# Generation 369: Best Distance = 9840
# Generation 370: Best Distance = 9840
# Generation 371: Best Distance = 9840
# Generation 372: Best Distance = 9840
# Generation 373: Best Distance = 9840
# Generation 374: Best Distance = 9840
# Generation 375: Best Distance = 9840
# Generation 376: Best Distance = 9840
# Generation 377: Best Distance = 9840
# Generation 378: Best Distance = 9840
# Generation 379: Best Distance = 9840
# Generation 380: Best Distance = 9814
# Generation 381: Best Distance = 9814
# Generation 382: Best Distance = 9814
# Generation 383: Best Distance = 9814
# Generation 384: Best Distance = 9814
# Generation 385: Best Distance = 9814
# Generation 386: Best Distance = 9814
# Generation 387: Best Distance = 9814
# Generation 388: Best Distance = 9814
# Generation 389: Best Distance = 9814
# Generation 390: Best Distance = 9814
# Generation 391: Best Distance = 9814
# Generation 392: Best Distance = 9809
# Generation 393: Best Distance = 9809
# Generation 394: Best Distance = 9809
# Generation 395: Best Distance = 9808
# Generation 396: Best Distance = 9808
# Generation 397: Best Distance = 9808
# Generation 398: Best Distance = 9808
# Generation 399: Best Distance = 9808
# Generation 400: Best Distance = 9802
# Generation 401: Best Distance = 9802
# Generation 402: Best Distance = 9802
# Generation 403: Best Distance = 9802
# Generation 404: Best Distance = 9767
# Generation 405: Best Distance = 9767
# Generation 406: Best Distance = 9661
# Generation 407: Best Distance = 9661
# Generation 408: Best Distance = 9621
# Generation 409: Best Distance = 9621
# Generation 410: Best Distance = 9621
# Generation 411: Best Distance = 9621
# Generation 412: Best Distance = 9598
# Generation 413: Best Distance = 9598
# Generation 414: Best Distance = 9598
# Generation 415: Best Distance = 9598
# Generation 416: Best Distance = 9598
# Generation 417: Best Distance = 9598
# Generation 418: Best Distance = 9598
# Generation 419: Best Distance = 9598
# Generation 420: Best Distance = 9598
# Generation 421: Best Distance = 9598
# Generation 422: Best Distance = 9598
# Generation 423: Best Distance = 9598
# Generation 424: Best Distance = 9598
# Generation 425: Best Distance = 9598
# Generation 426: Best Distance = 9598
# Generation 427: Best Distance = 9598
# Generation 428: Best Distance = 9598
# Generation 429: Best Distance = 9598
# Generation 430: Best Distance = 9598
# Generation 431: Best Distance = 9598
# Generation 432: Best Distance = 9598
# Generation 433: Best Distance = 9598
# Generation 434: Best Distance = 9598
# Generation 435: Best Distance = 9598
# Generation 436: Best Distance = 9598
# Generation 437: Best Distance = 9598
# Generation 438: Best Distance = 9598
# Generation 439: Best Distance = 9505
# Generation 440: Best Distance = 9505
# Generation 441: Best Distance = 9505
# Generation 442: Best Distance = 9505
# Generation 443: Best Distance = 9505
# Generation 444: Best Distance = 9505
# Generation 445: Best Distance = 9505
# Generation 446: Best Distance = 9505
# Generation 447: Best Distance = 9505
# Generation 448: Best Distance = 9505
# Generation 449: Best Distance = 9505
# Generation 450: Best Distance = 9505
# Generation 451: Best Distance = 9386
# Generation 452: Best Distance = 9386
# Generation 453: Best Distance = 9386
# Generation 454: Best Distance = 9386
# Generation 455: Best Distance = 9386
# Generation 456: Best Distance = 9386
# Generation 457: Best Distance = 9386
# Generation 458: Best Distance = 9386
# Generation 459: Best Distance = 9386
# Generation 460: Best Distance = 9386
# Generation 461: Best Distance = 9386
# Generation 462: Best Distance = 9386
# Generation 463: Best Distance = 9386
# Generation 464: Best Distance = 9386
# Generation 465: Best Distance = 9386
# Generation 466: Best Distance = 9386
# Generation 467: Best Distance = 9386
# Generation 468: Best Distance = 9386
# Generation 469: Best Distance = 9386
# Generation 470: Best Distance = 9386
# Generation 471: Best Distance = 9386
# Generation 472: Best Distance = 9386
# Generation 473: Best Distance = 9386
# Generation 474: Best Distance = 9386
# Generation 475: Best Distance = 9386
# Generation 476: Best Distance = 9386
# Generation 477: Best Distance = 9386
# Generation 478: Best Distance = 9386
# Generation 479: Best Distance = 9386
# Generation 480: Best Distance = 9386
# Generation 481: Best Distance = 9386
# Generation 482: Best Distance = 9386
# Generation 483: Best Distance = 9386
# Generation 484: Best Distance = 9386
# Generation 485: Best Distance = 9386
# Generation 486: Best Distance = 9386
# Generation 487: Best Distance = 9233
# Generation 488: Best Distance = 9233
# Generation 489: Best Distance = 9233
# Generation 490: Best Distance = 9233
# Generation 491: Best Distance = 9233
# Generation 492: Best Distance = 9233
# Generation 493: Best Distance = 9233
# Generation 494: Best Distance = 9233
# Generation 495: Best Distance = 9233
# Generation 496: Best Distance = 9233
# Generation 497: Best Distance = 9233
# Generation 498: Best Distance = 9233
# Generation 499: Best Distance = 9233
# Best solution found: [27, 28, 12, 25, 44, 1, 22, 21, 42, 7, 2, 30, 29, 16, 46, 48, 43, 10, 9, 8, 41, 19, 45, 34, 35, 36, 49, 32, 18, 31, 23, 20, 50, 47, 26, 13, 14, 52, 11, 51, 33, 4, 6, 24, 38, 5, 15, 40, 37, 39, 3, 17] with distance 9233
